# %%
# %matplotlib inline

# %%
from config import config

import numpy as np
import psycopg2 as pg2
import matplotlib.pyplot as plt
from astropy.time import Time
import astropy.io.fits as iof
from astropy import units as u
from astropy.coordinates import SkyCoord
import pymongo
import certifi
import sys
import csv
import re
from datetime import datetime
from astropy.io import fits
from astropy.io.fits import HDUList

# %%
# Query GOTO DB
def query_GOTO_db():
    '''
    Queries the GOTO image db
    '''

    dbconn = pg2.connect(dbname='gotophoto_photometry', user='gotoreadonly', password='H4iidNHr', host='goto-observatory.warwick.ac.uk',port='522')
    image_db='image'
    cursor = dbconn.cursor()
   # cursor.execute("SELECT * FROM image")
    cursor.execute("SELECT * FROM image limit 100")
    columns = [column[0] for column in cursor.description]
    rows = list(cursor)

    file_table = []
    for row in rows:
        file_table.append(dict(zip(columns, row)))

    cursor.close()
    dbconn.close()

    return file_table

# %%
gotodb = query_GOTO_db()

# %%
x = gotodb

# %%
# connect to MongoDB server
cluster = pymongo.MongoClient("mongodb+srv://NARIT:cNarit73@cluster0.p42in.mongodb.net/test")
db = cluster['star']
collection = db["GOTO"]
collection.drop()
print("Connecting to the MongoDB database...")
# Out:
# Connecting to the MongoDB database...

# %%
##insert Object to MongoDB
result = collection.insert_many(x)
print(result.inserted_ids)
cluster.close()
# Out:
# [ObjectId('62bfa934f5bc008e4cee81da'), ObjectId('62bfa934f5bc008e4cee81db'), ObjectId('62bfa934f5bc008e4cee81dc'), ObjectId('62bfa934f5bc008e4cee81dd'), ObjectId('62bfa934f5bc008e4cee81de'), ObjectId('62bfa934f5bc008e4cee81df'), ObjectId('62bfa934f5bc008e4cee81e0'), ObjectId('62bfa934f5bc008e4cee81e1'), ObjectId('62bfa934f5bc008e4cee81e2'), ObjectId('62bfa934f5bc008e4cee81e3'), ObjectId('62bfa934f5bc008e4cee81e4'), ObjectId('62bfa934f5bc008e4cee81e5'), ObjectId('62bfa934f5bc008e4cee81e6'), ObjectId('62bfa934f5bc008e4cee81e7'), ObjectId('62bfa934f5bc008e4cee81e8'), ObjectId('62bfa934f5bc008e4cee81e9'), ObjectId('62bfa934f5bc008e4cee81ea'), ObjectId('62bfa934f5bc008e4cee81eb'), ObjectId('62bfa934f5bc008e4cee81ec'), ObjectId('62bfa934f5bc008e4cee81ed'), ObjectId('62bfa934f5bc008e4cee81ee'), ObjectId('62bfa934f5bc008e4cee81ef'), ObjectId('62bfa934f5bc008e4cee81f0'), ObjectId('62bfa934f5bc008e4cee81f1'), ObjectId('62bfa934f5bc008e4cee81f2'), ObjectId('62bfa934f5bc008e4cee81f3'), ObjectId(
# ...
